# %% [markdown]
# # Laboratorio 1 - Programación orientada a objetos

# %%
import random

poblacion_ciudad = 500
N=4
M=4

# %%
class Celda:
    
    def __init__(self, m, n):
        self.m = m
        self.n = n
        self.ninos_sin_prob = [] 
        self.ninos_prob_card =[]
        self.ninos_prob_resp = []
        self.ninos_ambos_prob = []
        self.adultos_sin_prob = [] 
        self.adultos_prob_card =[]
        self.adultos_prob_resp = []
        self.adultos_ambos_prob = []
        self.ancianos_sin_prob = [] 
        self.ancianos_prob_card =[]
        self.ancianos_prob_resp = []
        self.ancianos_ambos_prob = []
        
    def poblacion_total(self):
        poblacion_total = casos_tolen(self.ninos_sin_prob) + len(self.ninos_prob_card) + len(self.ninos_prob_respL) + len(self.ninos_ambos_prob) + len(self.adultos_sin_prob) + len(self.adultos_prob_card) + len(self.adultos_prob_resp) + len(self.adultos_ambos_prob) + len(self.ancianos_sin_prob) + len(self.ancianos_prob_card) + len(self.ancianos_prob_resp) + len(self.ancianos_ambos_prob)
        return (poblacion_total)
    
    def casos_influenza(self):
        casos_inluenza = 0
        for persona in self.ninos_sin_prob:
            if persona.influenza == True:
                casos_influenza += 1
        for persona in self.ninos_prob_card:
            if persona.influenza == True:
                casos_influenza += 1   
        for persona in self.ninos_prob_resp:
            if persona.influenza == True:
                casos_influenza += 1       
        for persona in self.ninos_ambos_prob:
            if persona.influenza == True:
                casos_influenza += 1
        for persona in self.adultos_sin_prob:
            if persona.influenza == True:
                casos_influenza += 1
        for persona in self.adultos_prob_card:
            if persona.influenza == True:
                casos_influenza += 1   
        for persona in self.adultos_prob_resp:
            if persona.influenza == True:
                casos_influenza += 1       
        for persona in self.adultos_ambos_prob:
            if persona.influenza == True:
                casos_influenza += 1 
        for persona in self.ancianos_sin_prob:
            if persona.influenza == True:
                casos_influenza += 1
        for persona in self.ancianos_prob_card:
            if persona.influenza == True:
                casos_influenza += 1   
        for persona in self.ancianos_prob_resp:
            if persona.influenza == True:
                casos_influenza += 1       
        for persona in self.ancianos_ambos_prob:
            if persona.influenza == True:
                casos_influenza += 1
        return (casos_influenza)
                
    def casos_corona(self):
        casos_corona = 0
        for persona in self.ninos_sin_prob:
            if persona.corona == True:
                casos_corona += 1
        for persona in self.ninos_prob_card:
            if persona.corona == True:
                casos_corona += 1   
        for persona in self.ninos_prob_resp:
            if persona.corona == True:
                casos_corona += 1       
        for persona in self.ninos_ambos_prob:
            if persona.corona == True:
                casos_corona += 1
        for persona in self.adultos_sin_prob:
            if persona.corona == True:
                casos_corona += 1
        for persona in self.adultos_prob_card:
            if persona.corona == True:
                casos_corona += 1   
        for persona in self.adultos_prob_resp:
            if persona.corona == True:
                casos_corona += 1       
        for persona in self.adultos_ambos_prob:
            if persona.corona == True:
                casos_corona += 1 
        for persona in self.ancianos_sin_prob:
            if persona.corona == True:
                casos_corona += 1
        for persona in self.ancianos_prob_card:
            if persona.corona == True:
                casos_corona += 1   
        for persona in self.ancianos_prob_resp:
            if persona.corona == True:
                casos_corona += 1       
        for persona in self.ancianos_ambos_prob:
            if persona.corona == True:
                casos_corona += 1
        return (casos_corona)

# %%
                               
    
class Nino_sin_prob():
    
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = corona_celda/poblacion_total
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2            
            
class Nino_prob_resp():
    
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 1.1*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*1.1*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2 

class Nino_prob_card():
    
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 1.1*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*1.1*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2 
    
class Nino_ambos_prob():
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 1.1*1.1*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*1.1*1.1*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2 
    
class Adulto_sin_prob():
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 1.3*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*1.3*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2            
             

class Adulto_prob_resp():
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 2*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*2*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2  

class Adulto_prob_card():
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 2*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*2*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2  
    
class Adulto_ambos_prob():
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 1.1*2*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*1.1*2*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2  
    
class Anciano_sin_prob():
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 1.5*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*1.5*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2            
            
    
class Anciano_prob_resp():
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 3*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*3*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2            
            

class Anciano_prob_card():  
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 2*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*2*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2            
            
    
class Anciano_ambos_prob(): 
    def __init__ (self):
        self.prob_corona = 0
        self.prob_influenza = 0
        self.corona = False
        self.influenza = False
        self.vacuna = False
    
    def prob_de_contagio(self, corona_celda, influenza_celda, poblacion_total):
        if self.corona and self.influenza == False:
            prob_influenza = influenza_celda/poblacion_total
            prob_corona = 12*(corona_celda/poblacion_total)
        if self.influenza == True and self.corona == False:
            prob_corona == 1.1*12*(corona_celda/poblacion_total)
        if self.vacuna == True:
            prob_corona = prob_corona/2

# %%
def inicializar_ciudad(M,N):
    ciudad = []
    for i in range(M):
        ciudad.append([])
        for j in range (N):
            ciudad[i].append(0)
    return(ciudad)
    
def poblar_ciudad(ciudad,poblacion_total, parametros=[]):
    
    if parametros == []:
        celdas = 0
        ninos_sin_prob = [] 
        ninos_prob_card =[]
        ninos_prob_resp = []
        ninos_ambos_prob = []
        adultos_sin_prob = [] 
        adultos_prob_card =[]
        adultos_prob_resp = []
        adultos_ambos_prob = []
        ancianos_sin_prob = [] 
        ancianos_prob_card =[]
        ancianos_prob_resp = []
        ancianos_ambos_prob = []
        for i in range(len(ciudad)):
            for j in range(len(ciudad[i])):
                parametros.append([i,j,ninos_sin_prob,ninos_prob_card, ninos_prob_resp, ninos_ambos_prob, adultos_sin_prob, adultos_prob_card, adultos_prob_resp, adultos_ambos_prob,ancianos_sin_prob, ancianos_prob_card, ancianos_prob_resp, ancianos_ambos_prob])
                celdas +=1
        
        aux =[]
        for i in range (celdas):
            aux.append(0)
        for i in range (poblacion_total):
            a = random.randrange(celdas)
            aux[a-1] += 1
        
       
        for i in parametros:
            
            cont = 0
            c2 = 0
            while c2 <= aux[cont]: 
                a = random.choices(('nino_sin_prob','nino_prob_resp', 'nino_prob_card', 'nino_ambos_prob','adulto_sin_prob', 'adulto_prob_card', 'adulto_prob_resp', 'adulto_ambos_prob','anciano_sin_prob', 'anciano_prob_card', 'anciano_prob_resp', 'anciano_ambos_prob'),[10,7,7,4,9,9,9,8,5,10,9,11])
                
                if a[0] == 'nino_sin_prob':
                    nsp = Nino_sin_prob()
                    i[2].append(nsp)
                elif a[0] == 'nino_prob_card':
                    npc = Nino_prob_card()
                    i[3].append(npc)
                elif a[0] == 'nino_prob_resp':
                    p = Nino_prob_resp()
                    i[4].append(p)
                elif a[0] == 'nino_ambos_prob':
                    p = Nino_ambos_prob()
                    i[5].append(p)
                elif a[0] == 'adulto_sin_prob':
                    p = Adulto_sin_prob()
                    i[6].append(p)
                elif a[0] == 'adulto_prob_card':
                    p = Adulto_prob_card()
                    i[7].append(p)
                elif a[0] == 'adulto_prob_resp':
                    p = Adulto_prob_resp()
                    i[8].append(p)
                elif a[0] == 'adulto_ambos_prob':
                    p = Adulto_ambos_prob()
                    i[9].append(p)
                elif a[0] == 'anciano_sin_prob':
                    p = Anciano_sin_prob()
                    i[10].append(p)
                elif a[0] == 'anciano_prob_card':
                    p = Adulto_prob_card()
                    i[11].append(p)
                elif a[0] == 'anciano_prob_resp':
                    p = Anciano_prob_resp()
                    i[12].append(p)
                elif a[0] == 'anciano_ambos_prob':
                    p = Anciano_ambos_prob()
                    i[13].append(p)
                c2 += 1
            cont +=1
        
        for i in parametros:
            ciudad[i[0]][i[1]] = i[2:]
        return (ciudad)
    else:
        for i in parametros:
            ciudad[i[0]][i[1]] = i[2:]
        return (ciudad)

# %%
class Ciudad2():
    def __init__(self,M, N, poblacion_total):
        self.M = M
        self.N = N
        self.poblacion_total = poblacion_total
        self.ciudad = []

    def inicializar_ciudad(self):
        
        for i in range(M):
            self.ciudad.append([])
            for j in range (N):
                self.ciudad[i].append(Celda(i,j))
        return(self.ciudad)

    def poblar_ciudad(self,parametros=[]):
        if parametros == []:
            celdas = 0

            for i in range(len(self.ciudad)):
                for j in range(len(self.ciudad[i])):
                    parametros.append([i,j,Celda(i,j).ninos_sin_prob,Celda(i,j).ninos_prob_card, Celda(i,j).ninos_prob_resp, Celda(i,j).ninos_ambos_prob, Celda(i,j).adultos_sin_prob, Celda(i,j).adultos_prob_card, Celda(i,j).adultos_prob_resp, Celda(i,j).adultos_ambos_prob,Celda(i,j).ancianos_sin_prob, Celda(i,j).ancianos_prob_card, Celda(i,j).ancianos_prob_resp, Celda(i,j).ancianos_ambos_prob])
                    celdas +=1
            aux =[]
            for i in range (celdas):
                aux.append(0)
            for i in range (self.poblacion_total):
                a = random.randrange(celdas)
                aux[a-1] += 1

            for i in parametros:
                cont = 0
                c2 = 0
                while c2 <= aux[cont]: 
                    a = random.choices(('nino_sin_prob','nino_prob_resp', 'nino_prob_card', 'nino_ambos_prob','adulto_sin_prob', 'adulto_prob_card', 'adulto_prob_resp', 'adulto_ambos_prob','anciano_sin_prob', 'anciano_prob_card', 'anciano_prob_resp', 'anciano_ambos_prob'),[10,7,7,4,9,9,9,8,5,10,9,11])
                    if a[0] == 'nino_sin_prob':
                        nsp = Nino_sin_prob()
                        i[2].append(nsp)
                    elif a[0] == 'nino_prob_card':
                        npc = Nino_prob_card()
                        i[3].append(npc)
                    elif a[0] == 'nino_prob_resp':
                        p = Nino_prob_resp()
                        i[4].append(p)
                    elif a[0] == 'nino_ambos_prob':
                        p = Nino_ambos_prob()
                        i[5].append(p)
                    elif a[0] == 'adulto_sin_prob':
                        p = Adulto_sin_prob()
                        i[6].append(p)
                    elif a[0] == 'adulto_prob_card':
                        p = Adulto_prob_card()
                        i[7].append(p)
                    elif a[0] == 'adulto_prob_resp':
                        p = Adulto_prob_resp()
                        i[8].append(p)
                    elif a[0] == 'adulto_ambos_prob':
                        p = Adulto_ambos_prob()
                        i[9].append(p)
                    elif a[0] == 'anciano_sin_prob':
                        p = Anciano_sin_prob()
                        i[10].append(p)
                    elif a[0] == 'anciano_prob_card':
                        p = Adulto_prob_card()
                        i[11].append(p)
                    elif a[0] == 'anciano_prob_resp':
                        p = Anciano_prob_resp()
                        i[12].append(p)
                    elif a[0] == 'anciano_ambos_prob':
                        p = Anciano_ambos_prob()
                        i[13].append(p)
                    c2 += 1
                cont +=1

            for i in parametros:
                self.ciudad[i[0]][i[1]] = i[2:]
            return (self.ciudad)
        else:
            for i in parametros:
                self.ciudad[i[0]][i[1]] = i[2:]
            return (self.ciudad)
        
    def paciente_cero(self):
        m0 = random.randrange(self.M)
        n0 = random.randrange(self.N)
        cat = random.randrange(11)
        pers = random.randrange(len(self.ciudad[m0][n0][cat]))
        self.ciudad[m0][n0][cat][pers].corona = True
        m1 = random.randrange(self.M)
        n1 = random.randrange(self.N)
        cat1 = random.randrange(11)
        pers1 = random.randrange(len(self.ciudad[m1][n1][cat1]))
        self.ciudad[m1][n1][cat1][pers1].corona = True
        print(self.ciudad[m0][n0][cat][pers-1].prob_de_contagio(Celda(m0,n0).casos_corona(),Celda(m0,n0).casos_influenza(),Celda(m0,n0).poblacion_total()))
        return (self.ciudad)
    
    #def contagio_zonal(self):

# %%
ciudad = inicializar_ciudad(M,N) 
#print(ciudad)
ciudad = poblar_ciudad(ciudad,50)
#print(ciudad)
